# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import math
df = pd.read_csv("pokemon_data.csv")
print(df.head(10))
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                    Ivysaur  Grass  Poison  60      62       63       80
# 2  3                   Venusaur  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %%
#new_df=df.loc[(df["Type 1"] == "Grass") & (df["Type 2"] == "Poison") & (df["HP"]>70)]
#df.loc[~df["Name"].str.contains("Mega")]
#new_df = new_df.reset_index(drop=True)
#new_df
import re
new_df=df.loc[df["Name"].str.contains("^A[a-z]", regex=True)]
new_df
# Out:
#        #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 29    24                      Arbok    Poison     NaN   60      85       69
# 64    59                   Arcanine      Fire     NaN   90     110       80
# 68    63                       Abra   Psychic     NaN   25      20       15
# 70    65                   Alakazam   Psychic     NaN   55      50       45
# 71    65      AlakazamMega Alakazam   Psychic     NaN   55      50       65
# 153  142                 Aerodactyl      Rock  Flying   80     105       65
# 154  142  AerodactylMega Aerodactyl      Rock  Flying   80     135       85
# 156  144                   Articuno       Ice  Flying   90      85      100
# 182  168                    Ariados       Bug  Poison   70      90       70
# 195  181                   Ampharos  Electric     NaN   90      75       85
# 196  181      AmpharosMega Ampharos  Electric  Dragon   90      95      105
# ...

# %%
#conditional changes
#df.loc[df["HP"] > 25, "Legendary"] = True
#df
df = pd.read_csv("modified.csv")
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
sns.countplot(x="Legendary",data = df)

# %%
sns.countplot(x="Generation",hue="Legendary",data = df)

# %%
df["Total"].plot.hist()

# %%
#new_df=df.groupby(["Type 1"]).mean().sort_values ("Total", ascending=False)
#new_df
df = pd.read_csv("modified.csv")
df["count"]=1

df.groupby(["Type 1", "Type 2"]).count()["count"].sort_values(ascending=False)
# Out:
# Type 1    Type 2
# Normal    Flying    24
# Grass     Poison    15
# Bug       Flying    14
#           Poison    12
# Water     Ground    10
#                     ..
# Electric  Ice        1
#           Grass      1
#           Fire       1
#           Fairy      1
# Water     Steel      1
# Name: count, Length: 136, dtype: int64

# %%
df.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df.dropna(inplace=True)
embark=pd.get_dummies(df["Legendary"],drop_first=True)
# Out:
#      True
# 0       0
# 1       0
# 2       0
# 3       0
# 6       0
# ..    ...
# 795     1
# 796     1
# 797     1
# 798     1
# 799     1
#
# [414 rows x 1 columns]

# %%
#working with large groups of data
df = pd.read_csv("modified.csv")
for df in pd.read_csv("modified.csv",chunksize=10):
    results = df.groupby(["Type 1"]).count()
    new_df = pd.concat([new_df,results])
    print(new_df)
# Out:
#          #                       Name    Type 1  Type 2   HP  Attack  Defense  \
# 29      24                      Arbok    Poison     NaN   60      85       69
# 64      59                   Arcanine      Fire     NaN   90     110       80
# 68      63                       Abra   Psychic     NaN   25      20       15
# 70      65                   Alakazam   Psychic     NaN   55      50       45
# 71      65      AlakazamMega Alakazam   Psychic     NaN   55      50       65
# 153    142                 Aerodactyl      Rock  Flying   80     105       65
# 154    142  AerodactylMega Aerodactyl      Rock  Flying   80     135       85
# 156    144                   Articuno       Ice  Flying   90      85      100
# 182    168                    Ariados       Bug  Poison   70      90       70
# 195    181                   Ampharos  Electric     NaN   90      75       85
# 196    181      AmpharosMega Ampharos  Electric  Dragon   90      95      105
# ...
